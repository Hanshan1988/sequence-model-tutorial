# %% [markdown]
# # Multilayer Perceptron

# %% [markdown]
# ## Import Pacakges

# %%
import tensorflow as tf
import torch
from torch.utils import data
from torch import nn

import sys
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from mlxtend.plotting import plot_decision_regions

from d2l import tensorflow as d2l_tf
from d2l import torch as d2l_torch

# %%
print(tf.__version__)
# Out:
# 2.8.0

# %%
print(torch.__version__)
# Out:
# 1.8.0

# %%
plt.rcParams["figure.figsize"] = (8, 8)

# %% [markdown]
# * https://www.tensorflow.org/tutorials/keras/classification
# * https://www.tensorflow.org/tutorials/keras/text_classification
# * https://towardsdatascience.com/how-to-train-a-classification-model-with-tensorflow-in-10-minutes-fd2b7cfba86
# * https://www.kaggle.com/code/salehahmedrony/deep-learning-decision-boundary/notebook

# %% [markdown]
# ## Problem - Classfication

# %% [markdown]
# ### Global Variables

# %%
LEARNING_RATE = 0.03
NUM_EPOCHS = 5
BATCH_SIZE = 8
INIT_STDDEV = 0.01 # random initialisation from normal distribution

# %% [markdown]
# ### Data Preparation

# %%
base_colors = list(plt.cm.colors.BASE_COLORS.keys())
X, y = datasets.make_moons(n_samples=200, noise=.1, random_state=0)
plt.scatter(X[:,0], X[:, 1], color=[base_colors[int(i)] for i in y])

# %%
features, labels = tf.constant(X), tf.constant(y)

# %%
features[:10], labels[:10]
# Out:
# (<tf.Tensor: shape=(10, 2), dtype=float64, numpy=
#  array([[ 0.79235735,  0.50264857],
#         [ 1.63158315, -0.4638967 ],
#         [-0.06710927,  0.26776706],
#         [-1.04412427, -0.18260761],
#         [ 1.76704822, -0.19860987],
#         [ 1.90607398, -0.07109159],
#         [ 0.96219213,  0.26198607],
#         [ 0.88681385, -0.48489624],
#         [ 0.8689352 ,  0.36109278],
#         [ 1.15352953, -0.57235293]])>,
#  <tf.Tensor: shape=(10,), dtype=int64, numpy=array([0, 1, 1, 0, 1, 1, 0, 1, 0, 1])>)

# %%
def load_array(data_arrays, batch_size, is_train=True):  #@save
    """Construct a TensorFlow data iterator."""
    dataset = tf.data.Dataset.from_tensor_slices(data_arrays)
    if is_train:
        dataset = dataset.shuffle(buffer_size=1000)
    dataset = dataset.batch(batch_size)
    return dataset

# %%
batch_size = BATCH_SIZE
data_iter = load_array((features, labels), batch_size)

# %% [markdown]
# ---

# %%
features = torch.tensor([[0., 0.],
                         [0., 1.],
                         [1., 0.],
                         [1., 1.]])

labels = torch.tensor([[0],
                       [1],
                       [1],
                       [0]])

# %%
features, labels
# Out:
# (tensor([[0., 0.],
#          [0., 1.],
#          [1., 0.],
#          [1., 1.]]),
#  tensor([[0],
#          [1],
#          [1],
#          [0]]))

# %%
def load_array_pt(data_arrays, batch_size, is_train=True):  #@save
    """Construct a PyTorch data iterator."""
    dataset = data.TensorDataset(*data_arrays)
    return data.DataLoader(dataset, batch_size, shuffle=is_train)

# %%
data_iter = load_array_pt((features, labels), BATCH_SIZE)

# %% [markdown]
# ### Model Training

# %% [markdown]
# #### TF Keras Sequential API

# %% [markdown]
# Need to rerun tensorflow data prep part!

# %%
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_pred - y_true)))

# %%
initializer = tf.initializers.RandomNormal(stddev=INIT_STDDEV)
loss = tf.keras.losses.BinaryCrossentropy(from_logits=True)
# tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True) for multiclass
optimizer = tf.keras.optimizers.SGD(learning_rate=LEARNING_RATE)
metrics=[tf.metrics.BinaryAccuracy(threshold=0.0), 'accuracy']

# %% [markdown]
# **A. Model architecture**

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1, activation='sigmoid', input_dim=2,
                          kernel_initializer=initializer)
])

# # Alternatively
# model = tf.keras.Sequential()
# model.add(tf.keras.layers.InputLayer(input_shape=(2, ))
# model.add(tf.keras.layers.Dense(1, kernel_initializer=initializer))

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=optimizer,
              loss=loss,
              metrics=metrics)
model.fit(data_iter,
          epochs=NUM_EPOCHS)
# Out:
# Epoch 1/5
# /Users/work/miniforge3/envs/py38/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 2022-04-14 20:44:30.035304: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 25/25 [==============================] - 0s 6ms/step - loss: 0.6640 - binary_accuracy: 0.6525 - accuracy: 0.7300
# Epoch 2/5
# 25/25 [==============================] - 0s 7ms/step - loss: 0.6071 - binary_accuracy: 0.5000 - accuracy: 0.8000
# Epoch 3/5
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5636 - binary_accuracy: 0.5000 - accuracy: 0.8100
# Epoch 4/5
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5299 - binary_accuracy: 0.5000 - accuracy: 0.8100
# Epoch 5/5
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5027 - binary_accuracy: 0.5000 - accuracy: 0.8100

# %%
plot_decision_regions(X=X, y=y, clf=model, legend=2)
# Out:
# 2022-04-14 20:44:32.667993: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# <AxesSubplot:>

# %% [markdown]
# * The input layer can be ommited here and model can be fitted on input data at a later stage. This way however, `model.summary()` can only be called later when the input data shape is known to the object.
# * Any types of feature preprocessing e.g. normalisation (`tf.keras.layers.Normalization`) can also be included in the sequential steps as the initial layer.

# %% [markdown]
# **A. Training process**

# %%
def train(model, features, labels, batch_size, loss, num_epochs, optimizer):
    data_iter = load_array((features, labels), batch_size)
    for epoch in range(num_epochs):
        for X, y in data_iter:
            with tf.GradientTape() as tape:
                l = loss(model(X, training=True), y)
            grads = tape.gradient(l, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
        l = loss(model(features), labels)
        print(f'epoch {epoch + 1}, loss {l:f}')

# %%
train(model, features, labels, BATCH_SIZE, loss, NUM_EPOCHS, optimizer)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/sd/mz_l847n579df0n5l438fcl00000gr/T/ipykernel_66421/2416208795.py in <module>
# ----> 1 train(model, features, labels, BATCH_SIZE, loss, NUM_EPOCHS, optimizer)
#
# /var/folders/sd/mz_l847n579df0n5l438fcl00000gr/T/ipykernel_66421/3365424075.py in train(model, features, labels, batch_size, loss, num_epochs, optimizer)
#       4         for X, y in data_iter:
#       5             with tf.GradientTape() as tape:
# ----> 6                 l = loss(model(X, training=True), y)
#       7             grads = tape.gradient(l, model.trainable_variables)
#       8             optimizer.apply_gradients(zip(grads, model.trainable_variables))
#
# ~/miniforge3/envs/py38/lib/python3.8/site-packages/keras/losses.py in __call__(self, y_true, y_pred, sample_weight)
#     139       else:
#     140         call_fn = tf.__internal__.autograph.tf_convert(self.call, tf.__internal__.autograph.control_status_ctx())
# --> 141       losses = call_fn(y_true, y_pred)
#     142       return losses_utils.compute_weighted_loss(
#     143           losses, sample_weight, reduction=self._get_reduction())
#
# ~/miniforge3/envs/py38/lib/python3.8/site-packages/keras/losses.py in call(self, y_true, y_pred)
#     243
#     244     ag_fn = tf.__internal__.autograph.tf_convert(self.fn, tf.__internal__.autograph.control_status_ctx())
# --> 245     return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     246
#     247   def get_config(self):
#
# ~/miniforge3/envs/py38/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# ~/miniforge3/envs/py38/lib/python3.8/site-packages/keras/losses.py in binary_crossentropy(y_true, y_pred, from_logits, label_smoothing, axis)
#    1921   y_pred = tf.convert_to_tensor(y_pred)
#    1922   y_true = tf.cast(y_true, y_pred.dtype)
# -> 1923   label_smoothing = tf.convert_to_tensor(label_smoothing, dtype=y_pred.dtype)
#    1924
#    1925   def _smooth_labels():
#
# TypeError: Cannot convert 0.0 to EagerTensor of dtype int64

# %% [markdown]
# **B. Model architecture (Repeated)**

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %% [markdown]
# * Here we didn't define the input layer so naturally we cannot call `model.summary()` as the object doesn't know anything about the shape of the input data

# %% [markdown]
# **B. Compile model then train**

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.05),
              loss=loss,
              metrics=metrics)
model.fit(data_iter,
          epochs=20)
# Out:
# Epoch 1/20
#  1/25 [>.............................] - ETA: 9s - loss: 5.2532e-05 - binary_accuracy: 0.5000 - accuracy: 1.0000
# 2022-04-14 20:51:49.767089: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 25/25 [==============================] - 1s 8ms/step - loss: 0.0877 - binary_accuracy: 0.5000 - accuracy: 0.9750
# Epoch 2/20
# 25/25 [==============================] - 0s 7ms/step - loss: 0.1213 - binary_accuracy: 0.5000 - accuracy: 0.9800
# Epoch 3/20
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0135 - binary_accuracy: 0.5000 - accuracy: 0.9950
# Epoch 4/20
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0048 - binary_accuracy: 0.5000 - accuracy: 1.0000
# Epoch 5/20
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0276 - binary_accuracy: 0.5000 - accuracy: 0.9900
# Epoch 6/20
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0602 - binary_accuracy: 0.5000 - accuracy: 0.9900
# Epoch 7/20
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0109 - binary_accuracy: 0.5000 - accuracy: 0.9950
# Epoch 8/20
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0121 - binary_accuracy: 0.5000 - accuracy: 0.9900
# Epoch 9/20
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0037 - binary_accuracy: 0.5000 - accuracy: 1.0000
# Epoch 10/20
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0045 - binary_accuracy: 0.5000 - accuracy: 1.0000
# Epoch 11/20
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0094 - binary_accuracy: 0.5000 - accuracy: 0.9950
# Epoch 12/20
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0258 - binary_accuracy: 0.5000 - accuracy: 0.9900
# Epoch 13/20
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0079 - binary_accuracy: 0.5000 - accuracy: 0.9950
# Epoch 14/20
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0091 - binary_accuracy: 0.5000 - accuracy: 0.9950
# Epoch 15/20
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0121 - binary_accuracy: 0.5000 - accuracy: 0.9950
# Epoch 16/20
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0123 - binary_accuracy: 0.5000 - accuracy: 0.9900
# Epoch 17/20
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0457 - binary_accuracy: 0.5000 - accuracy: 0.9950
# Epoch 18/20
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0579 - binary_accuracy: 0.5000 - accuracy: 0.9800
# Epoch 19/20
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0226 - binary_accuracy: 0.5000 - accuracy: 0.9950
# Epoch 20/20
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0170 - binary_accuracy: 0.5000 - accuracy: 0.9900

# %%
plot_decision_regions(X=X, y=y, clf=model, legend=2)
# Out:
# 2022-04-14 20:51:55.128721: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# <AxesSubplot:>

# %% [markdown]
# #### TF Keras Functional API

# %%
inputs = tf.keras.Input(shape=(2,))
# x = tf.keras.layers.Dense(10, activation="relu")(inputs)
outputs = tf.keras.layers.Dense(1)(inputs)

# %%
model = tf.keras.Model(inputs=inputs, outputs=outputs, name="linear_model")
model.summary()
# Out:
# Model: "linear_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 2)]               0
#
#  dense_3 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=optimizer,
              loss=loss,
              metrics=['mse', rmse])
model.fit(data_iter,
          epochs=NUM_EPOCHS)
# Out:
# Epoch 1/5
#  39/100 [==========>...................] - ETA: 0s - loss: 8.6179 - mse: 8.6179 - rmse: 2.2938
# 2022-03-31 18:42:05.860737: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 100/100 [==============================] - 1s 4ms/step - loss: 3.3768 - mse: 3.3768 - rmse: 0.9626
# Epoch 2/5
# 100/100 [==============================] - 0s 4ms/step - loss: 1.0781e-04 - mse: 1.0781e-04 - rmse: 0.0101
# Epoch 3/5
# 100/100 [==============================] - 0s 4ms/step - loss: 1.0195e-04 - mse: 1.0195e-04 - rmse: 0.0098
# Epoch 4/5
# 100/100 [==============================] - 0s 4ms/step - loss: 1.0211e-04 - mse: 1.0211e-04 - rmse: 0.0098
# Epoch 5/5
# 100/100 [==============================] - 0s 4ms/step - loss: 1.0137e-04 - mse: 1.0137e-04 - rmse: 0.0098

# %%
w = model.get_weights()[0]
print('error in estimating w', true_w - tf.reshape(w, true_w.shape))
b = model.get_weights()[1]
print('error in estimating b', true_b - b)
# Out:
# error in estimating w tf.Tensor([1.8048286e-04 4.8398972e-05], shape=(2,), dtype=float32)
# error in estimating b [-0.00080442]

# %%
print(w)
print(b)
# Out:
# [[ 1.9998195]
#  [-3.4000485]]
# [4.200804]

# %% [markdown]
# #### Pytorch

# %% [markdown]
# References
# * https://pytorch.org/docs/stable/generated/torch.nn.Module.html
# * https://medium.com/biaslyai/pytorch-linear-and-logistic-regression-models-5c5f0da2cb9
# * https://medium.com/biaslyai/pytorch-introduction-to-neural-network-feedforward-neural-network-model-e7231cff47cb

# %% [markdown]
# Need to rerun Pytorch data prep part first!

# %%
model = nn.Sequential(nn.Linear(2, 1))

# %%
def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.normal_(m.weight, std=INIT_STDDEV)

model.apply(init_weights)
loss = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=LEARNING_RATE)

# %%
def train(model, train_iter, loss, num_epochs, optimizer:
    for epoch in range(num_epochs):
        for X, y in train_iter:
            l = loss(model(X) ,y)
            optimizer.zero_grad()
            l.backward()
            optimizer.step()
        l = loss(model(features), labels)
        print(f'epoch {epoch + 1}, loss {l:f}')

# %%
train(model, data_iter, loss, NUM_EPOCHS, optimizer)
# Out:
# epoch 1, loss 0.000114
# epoch 2, loss 0.000104
# epoch 3, loss 0.000104
# epoch 4, loss 0.000104
# epoch 5, loss 0.000104

# %%
w = model[0].weight.data
print('error in estimating w:', true_w - w.reshape(true_w.shape))
b = model[0].bias.data
print('error in estimating b:', true_b - b)
# Out:
# error in estimating w: tensor([0.0002, 0.0007])
# error in estimating b: tensor([0.0005])

# %%
print(w)
print(b)
# Out:
# tensor([[ 1.9998, -3.0007]])
# tensor([3.9995])
